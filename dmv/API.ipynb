# %% [markdown]
# # <font>2.Interact with the OpenWeatherMap API using the API key to retrieve weather data for a specific location</font>

# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://api.openweathermap.org/data/2.5/forecast?lat=44.34&lon=10.99&appid=e44454e05905e9a70946cdaa454ac096' # <-- This is app id also known as api key, which you have to generate your own, and paste it here

#vurl ='https://api.openweathermap.org/data/2.5/weather?lat=44.34&lon=10.99&appid=307d11bca480dd730d99187c926&city_name=London'
response = requests.get(url)
data = response.json()
pretty_json = json.dumps(data,indent=4)
print(pretty_json)
# Out:
# {
#     "cod": "200",
#     "message": 0,
#     "cnt": 40,
#     "list": [
#         {
#             "dt": 1730754000,
#             "main": {
#                 "temp": 282.04,
#                 "feels_like": 282.04,
#                 "temp_min": 282.04,
#                 "temp_max": 282.33,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 91,
#                 "temp_kf": -0.29
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.25,
#                 "deg": 227,
#                 "gust": 0.64
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-04 21:00:00"
#         },
#         {
#             "dt": 1730764800,
#             "main": {
#                 "temp": 281.77,
#                 "feels_like": 281.36,
#                 "temp_min": 281.71,
#                 "temp_max": 281.77,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 88,
#                 "temp_kf": 0.06
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 1.38,
#                 "deg": 226,
#                 "gust": 0.86
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 00:00:00"
#         },
#         {
#             "dt": 1730775600,
#             "main": {
#                 "temp": 281.21,
#                 "feels_like": 281.21,
#                 "temp_min": 281.21,
#                 "temp_max": 281.21,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 43
#             },
#             "wind": {
#                 "speed": 1.33,
#                 "deg": 231,
#                 "gust": 0.81
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 03:00:00"
#         },
#         {
#             "dt": 1730786400,
#             "main": {
#                 "temp": 280.89,
#                 "feels_like": 280.35,
#                 "temp_min": 280.89,
#                 "temp_max": 280.89,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 72
#             },
#             "wind": {
#                 "speed": 1.39,
#                 "deg": 231,
#                 "gust": 0.88
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 06:00:00"
#         },
#         {
#             "dt": 1730797200,
#             "main": {
#                 "temp": 285.66,
#                 "feels_like": 284.77,
#                 "temp_min": 285.66,
#                 "temp_max": 285.66,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 958,
#                 "humidity": 69,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 0.72,
#                 "deg": 19,
#                 "gust": 0.42
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 09:00:00"
#         },
#         {
#             "dt": 1730808000,
#             "main": {
#                 "temp": 287.34,
#                 "feels_like": 286.56,
#                 "temp_min": 287.34,
#                 "temp_max": 287.34,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 67,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 99
#             },
#             "wind": {
#                 "speed": 1.88,
#                 "deg": 32,
#                 "gust": 0.83
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 12:00:00"
#         },
#         {
#             "dt": 1730818800,
#             "main": {
#                 "temp": 285.33,
#                 "feels_like": 284.85,
#                 "temp_min": 285.33,
#                 "temp_max": 285.33,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 86,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.37,
#                 "deg": 43,
#                 "gust": 1.42
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-05 15:00:00"
#         },
#         {
#             "dt": 1730829600,
#             "main": {
#                 "temp": 282.55,
#                 "feels_like": 282.55,
#                 "temp_min": 282.55,
#                 "temp_max": 282.55,
#                 "pressure": 1026,
#                 "sea_level": 1026,
#                 "grnd_level": 957,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.05,
#                 "deg": 212,
#                 "gust": 0.35
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 18:00:00"
#         },
#         {
#             "dt": 1730840400,
#             "main": {
#                 "temp": 282.01,
#                 "feels_like": 282.01,
#                 "temp_min": 282.01,
#                 "temp_max": 282.01,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.24,
#                 "deg": 225,
#                 "gust": 0.7
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-05 21:00:00"
#         },
#         {
#             "dt": 1730851200,
#             "main": {
#                 "temp": 281.19,
#                 "feels_like": 281.19,
#                 "temp_min": 281.19,
#                 "temp_max": 281.19,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 92,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 75
#             },
#             "wind": {
#                 "speed": 1.15,
#                 "deg": 235,
#                 "gust": 0.7
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 00:00:00"
#         },
#         {
#             "dt": 1730862000,
#             "main": {
#                 "temp": 280.62,
#                 "feels_like": 280.02,
#                 "temp_min": 280.62,
#                 "temp_max": 280.62,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 24
#             },
#             "wind": {
#                 "speed": 1.41,
#                 "deg": 228,
#                 "gust": 0.75
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 03:00:00"
#         },
#         {
#             "dt": 1730872800,
#             "main": {
#                 "temp": 280.45,
#                 "feels_like": 280.45,
#                 "temp_min": 280.45,
#                 "temp_max": 280.45,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 958,
#                 "humidity": 87,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 60
#             },
#             "wind": {
#                 "speed": 1.02,
#                 "deg": 233,
#                 "gust": 0.56
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 06:00:00"
#         },
#         {
#             "dt": 1730883600,
#             "main": {
#                 "temp": 284.8,
#                 "feels_like": 283.9,
#                 "temp_min": 284.8,
#                 "temp_max": 284.8,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 960,
#                 "humidity": 72,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 72
#             },
#             "wind": {
#                 "speed": 1.25,
#                 "deg": 17,
#                 "gust": 1.26
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 09:00:00"
#         },
#         {
#             "dt": 1730894400,
#             "main": {
#                 "temp": 286.79,
#                 "feels_like": 285.85,
#                 "temp_min": 286.79,
#                 "temp_max": 286.79,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 959,
#                 "humidity": 63,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 75
#             },
#             "wind": {
#                 "speed": 1.77,
#                 "deg": 35,
#                 "gust": 1.19
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 12:00:00"
#         },
#         {
#             "dt": 1730905200,
#             "main": {
#                 "temp": 284.82,
#                 "feels_like": 284.16,
#                 "temp_min": 284.82,
#                 "temp_max": 284.82,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 1.36,
#                 "deg": 32,
#                 "gust": 1.89
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-06 15:00:00"
#         },
#         {
#             "dt": 1730916000,
#             "main": {
#                 "temp": 281.56,
#                 "feels_like": 281.56,
#                 "temp_min": 281.56,
#                 "temp_max": 281.56,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 93
#             },
#             "wind": {
#                 "speed": 1.27,
#                 "deg": 225,
#                 "gust": 0.61
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 18:00:00"
#         },
#         {
#             "dt": 1730926800,
#             "main": {
#                 "temp": 280.68,
#                 "feels_like": 279.98,
#                 "temp_min": 280.68,
#                 "temp_max": 280.68,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 89,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 68
#             },
#             "wind": {
#                 "speed": 1.5,
#                 "deg": 232,
#                 "gust": 0.78
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-06 21:00:00"
#         },
#         {
#             "dt": 1730937600,
#             "main": {
#                 "temp": 280.05,
#                 "feels_like": 279.11,
#                 "temp_min": 280.05,
#                 "temp_max": 280.05,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 960,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03n"
#                 }
#             ],
#             "clouds": {
#                 "all": 44
#             },
#             "wind": {
#                 "speed": 1.63,
#                 "deg": 230,
#                 "gust": 0.95
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 00:00:00"
#         },
#         {
#             "dt": 1730948400,
#             "main": {
#                 "temp": 279.61,
#                 "feels_like": 278.77,
#                 "temp_min": 279.61,
#                 "temp_max": 279.61,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 960,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 1.49,
#                 "deg": 231,
#                 "gust": 0.89
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 03:00:00"
#         },
#         {
#             "dt": 1730959200,
#             "main": {
#                 "temp": 279.28,
#                 "feels_like": 278.42,
#                 "temp_min": 279.28,
#                 "temp_max": 279.28,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 960,
#                 "humidity": 90,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 85
#             },
#             "wind": {
#                 "speed": 1.47,
#                 "deg": 228,
#                 "gust": 0.71
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 06:00:00"
#         },
#         {
#             "dt": 1730970000,
#             "main": {
#                 "temp": 283.93,
#                 "feels_like": 283.07,
#                 "temp_min": 283.93,
#                 "temp_max": 283.93,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 77,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 83
#             },
#             "wind": {
#                 "speed": 1.1,
#                 "deg": 17,
#                 "gust": 0.97
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 09:00:00"
#         },
#         {
#             "dt": 1730980800,
#             "main": {
#                 "temp": 286.18,
#                 "feels_like": 285.37,
#                 "temp_min": 286.18,
#                 "temp_max": 286.18,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 70,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 65
#             },
#             "wind": {
#                 "speed": 2.14,
#                 "deg": 32,
#                 "gust": 1.16
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 12:00:00"
#         },
#         {
#             "dt": 1730991600,
#             "main": {
#                 "temp": 284.27,
#                 "feels_like": 283.74,
#                 "temp_min": 284.27,
#                 "temp_max": 284.27,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 76
#             },
#             "wind": {
#                 "speed": 1.56,
#                 "deg": 35,
#                 "gust": 2.34
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-07 15:00:00"
#         },
#         {
#             "dt": 1731002400,
#             "main": {
#                 "temp": 281.52,
#                 "feels_like": 281.52,
#                 "temp_min": 281.52,
#                 "temp_max": 281.52,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 88
#             },
#             "wind": {
#                 "speed": 0.79,
#                 "deg": 221,
#                 "gust": 0.24
#             },
#             "visibility": 8473,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 18:00:00"
#         },
#         {
#             "dt": 1731013200,
#             "main": {
#                 "temp": 281.25,
#                 "feels_like": 281.25,
#                 "temp_min": 281.25,
#                 "temp_max": 281.25,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 1.03,
#                 "deg": 244,
#                 "gust": 0.47
#             },
#             "visibility": 9721,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-07 21:00:00"
#         },
#         {
#             "dt": 1731024000,
#             "main": {
#                 "temp": 281.02,
#                 "feels_like": 281.02,
#                 "temp_min": 281.02,
#                 "temp_max": 281.02,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 960,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.99,
#                 "deg": 242,
#                 "gust": 0.39
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 00:00:00"
#         },
#         {
#             "dt": 1731034800,
#             "main": {
#                 "temp": 280.42,
#                 "feels_like": 280.42,
#                 "temp_min": 280.42,
#                 "temp_max": 280.42,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 100
#             },
#             "wind": {
#                 "speed": 0.89,
#                 "deg": 256,
#                 "gust": 0.34
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 03:00:00"
#         },
#         {
#             "dt": 1731045600,
#             "main": {
#                 "temp": 279.65,
#                 "feels_like": 279.65,
#                 "temp_min": 279.65,
#                 "temp_max": 279.65,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 96,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 76
#             },
#             "wind": {
#                 "speed": 1.14,
#                 "deg": 252,
#                 "gust": 0.55
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 06:00:00"
#         },
#         {
#             "dt": 1731056400,
#             "main": {
#                 "temp": 283.43,
#                 "feels_like": 282.79,
#                 "temp_min": 283.43,
#                 "temp_max": 283.43,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 961,
#                 "humidity": 87,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 802,
#                     "main": "Clouds",
#                     "description": "scattered clouds",
#                     "icon": "03d"
#                 }
#             ],
#             "clouds": {
#                 "all": 27
#             },
#             "wind": {
#                 "speed": 1.46,
#                 "deg": 12,
#                 "gust": 1.61
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 09:00:00"
#         },
#         {
#             "dt": 1731067200,
#             "main": {
#                 "temp": 284.58,
#                 "feels_like": 283.89,
#                 "temp_min": 284.58,
#                 "temp_max": 284.58,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 81,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 51
#             },
#             "wind": {
#                 "speed": 1.79,
#                 "deg": 27,
#                 "gust": 1.73
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 12:00:00"
#         },
#         {
#             "dt": 1731078000,
#             "main": {
#                 "temp": 283.95,
#                 "feels_like": 283.25,
#                 "temp_min": 283.95,
#                 "temp_max": 283.95,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 83,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 804,
#                     "main": "Clouds",
#                     "description": "overcast clouds",
#                     "icon": "04d"
#                 }
#             ],
#             "clouds": {
#                 "all": 86
#             },
#             "wind": {
#                 "speed": 1.18,
#                 "deg": 29,
#                 "gust": 1.52
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-08 15:00:00"
#         },
#         {
#             "dt": 1731088800,
#             "main": {
#                 "temp": 281.16,
#                 "feels_like": 281.16,
#                 "temp_min": 281.16,
#                 "temp_max": 281.16,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 803,
#                     "main": "Clouds",
#                     "description": "broken clouds",
#                     "icon": "04n"
#                 }
#             ],
#             "clouds": {
#                 "all": 74
#             },
#             "wind": {
#                 "speed": 0.87,
#                 "deg": 254,
#                 "gust": 0.58
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 18:00:00"
#         },
#         {
#             "dt": 1731099600,
#             "main": {
#                 "temp": 280.33,
#                 "feels_like": 279.66,
#                 "temp_min": 280.33,
#                 "temp_max": 280.33,
#                 "pressure": 1030,
#                 "sea_level": 1030,
#                 "grnd_level": 960,
#                 "humidity": 94,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 801,
#                     "main": "Clouds",
#                     "description": "few clouds",
#                     "icon": "02n"
#                 }
#             ],
#             "clouds": {
#                 "all": 11
#             },
#             "wind": {
#                 "speed": 1.44,
#                 "deg": 244,
#                 "gust": 0.78
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-08 21:00:00"
#         },
#         {
#             "dt": 1731110400,
#             "main": {
#                 "temp": 279.92,
#                 "feels_like": 279.28,
#                 "temp_min": 279.92,
#                 "temp_max": 279.92,
#                 "pressure": 1029,
#                 "sea_level": 1029,
#                 "grnd_level": 960,
#                 "humidity": 93,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 6
#             },
#             "wind": {
#                 "speed": 1.37,
#                 "deg": 240,
#                 "gust": 0.69
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 00:00:00"
#         },
#         {
#             "dt": 1731121200,
#             "main": {
#                 "temp": 279.56,
#                 "feels_like": 278.66,
#                 "temp_min": 279.56,
#                 "temp_max": 279.56,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 91,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 3
#             },
#             "wind": {
#                 "speed": 1.54,
#                 "deg": 231,
#                 "gust": 0.71
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 03:00:00"
#         },
#         {
#             "dt": 1731132000,
#             "main": {
#                 "temp": 279.19,
#                 "feels_like": 278.14,
#                 "temp_min": 279.19,
#                 "temp_max": 279.19,
#                 "pressure": 1028,
#                 "sea_level": 1028,
#                 "grnd_level": 959,
#                 "humidity": 88,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 2
#             },
#             "wind": {
#                 "speed": 1.62,
#                 "deg": 236,
#                 "gust": 0.84
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 06:00:00"
#         },
#         {
#             "dt": 1731142800,
#             "main": {
#                 "temp": 284.33,
#                 "feels_like": 283.25,
#                 "temp_min": 284.33,
#                 "temp_max": 284.33,
#                 "pressure": 1027,
#                 "sea_level": 1027,
#                 "grnd_level": 958,
#                 "humidity": 67,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 0.75,
#                 "deg": 332,
#                 "gust": 0.83
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 09:00:00"
#         },
#         {
#             "dt": 1731153600,
#             "main": {
#                 "temp": 286.44,
#                 "feels_like": 285.31,
#                 "temp_min": 286.44,
#                 "temp_max": 286.44,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 957,
#                 "humidity": 57,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 1.66,
#                 "deg": 14,
#                 "gust": 1.35
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 12:00:00"
#         },
#         {
#             "dt": 1731164400,
#             "main": {
#                 "temp": 284.33,
#                 "feels_like": 283.46,
#                 "temp_min": 284.33,
#                 "temp_max": 284.33,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 75,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01d"
#                 }
#             ],
#             "clouds": {
#                 "all": 0
#             },
#             "wind": {
#                 "speed": 0.82,
#                 "deg": 15,
#                 "gust": 0.72
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "d"
#             },
#             "dt_txt": "2024-11-09 15:00:00"
#         },
#         {
#             "dt": 1731175200,
#             "main": {
#                 "temp": 280.72,
#                 "feels_like": 279.99,
#                 "temp_min": 280.72,
#                 "temp_max": 280.72,
#                 "pressure": 1025,
#                 "sea_level": 1025,
#                 "grnd_level": 956,
#                 "humidity": 80,
#                 "temp_kf": 0
#             },
#             "weather": [
#                 {
#                     "id": 800,
#                     "main": "Clear",
#                     "description": "clear sky",
#                     "icon": "01n"
#                 }
#             ],
#             "clouds": {
#                 "all": 1
#             },
#             "wind": {
#                 "speed": 1.53,
#                 "deg": 215,
#                 "gust": 0.71
#             },
#             "visibility": 10000,
#             "pop": 0,
#             "sys": {
#                 "pod": "n"
#             },
#             "dt_txt": "2024-11-09 18:00:00"
#         }
#     ],
#     "city": {
#         "id": 3163858,
#         "name": "Zocca",
#         "coord": {
#             "lat": 44.34,
#             "lon": 10.99
#         },
#         "country": "IT",
#         "population": 4593,
#         "timezone": 3600,
#         "sunrise": 1730699848,
#         "sunset": 1730736103
#     }
# }

# %%
date_time = data['list'][0]['dt_txt']
date_time
# Out:
# '2024-11-04 21:00:00'

# %% [markdown]
# # 3.Extract relevant weather attributes such as temperature, humidity, wind speed, and  precipitation from the API response

# %%
data_struct = []
for record in data['list']:
    temp = record['main']['temp']
    humid = record['main']['humidity']
    wind_speed = record['wind']['speed']
    desp =record['weather'][0]['description']
    date_time = record['dt_txt']

    data_struct.append({'Temperature':temp,'Humidity':humid,'Wind Speed':wind_speed,'Weather Description':desp,'Date Time':date_time})

data_df = pd.DataFrame(data_struct)
data_df[['Date','Time']] = data_df['Date Time'].str.split(' ',expand=True)
data_df.head(10)
# Out:
#    Temperature  Humidity  Wind Speed Weather Description            Date Time  \
# 0       282.04        91        1.25           clear sky  2024-11-04 21:00:00
# 1       281.77        88        1.38           clear sky  2024-11-05 00:00:00
# 2       281.21        83        1.33    scattered clouds  2024-11-05 03:00:00
# 3       280.89        81        1.39       broken clouds  2024-11-05 06:00:00
# 4       285.66        69        0.72     overcast clouds  2024-11-05 09:00:00
# 5       287.34        67        1.88     overcast clouds  2024-11-05 12:00:00
# 6       285.33        86        1.37     overcast clouds  2024-11-05 15:00:00
# 7       282.55        93        1.05     overcast clouds  2024-11-05 18:00:00
# 8       282.01        93        1.24     overcast clouds  2024-11-05 21:00:00
# 9       281.19        92        1.15       broken clouds  2024-11-06 00:00:00
#
#          Date      Time
# 0  2024-11-04  21:00:00
# 1  2024-11-05  00:00:00
# 2  2024-11-05  03:00:00
# 3  2024-11-05  06:00:00
# 4  2024-11-05  09:00:00
# 5  2024-11-05  12:00:00
# 6  2024-11-05  15:00:00
# 7  2024-11-05  18:00:00
# 8  2024-11-05  21:00:00
# 9  2024-11-06  00:00:00

# %%
data_df.shape
# Out:
# (40, 7)

# %% [markdown]
# # 4.Clean and preprocess the retrieved data, handling missing values or inconsistent  formats.

# %%
data_df.isnull().sum()
# Out:
# Temperature            0
# Humidity               0
# Wind Speed             0
# Weather Description    0
# Date Time              0
# Date                   0
# Time                   0
# dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperature          40 non-null     float64
#  1   Humidity             40 non-null     int64
#  2   Wind Speed           40 non-null     float64
#  3   Weather Description  40 non-null     object
#  4   Date Time            40 non-null     object
#  5   Date                 40 non-null     object
#  6   Time                 40 non-null     object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 2.3+ KB

# %% [markdown]
# # 5.Perform data modeling to analyze weather patterns, such as calculating average temperature, maximum/minimum values, or trends over time.

# %%
data_df.describe()
# Out:
#        Temperature   Humidity  Wind Speed
# count    40.000000  40.000000   40.000000
# mean    282.370750  84.725000    1.315000
# std       2.346685  10.195493    0.324567
# min     279.190000  57.000000    0.720000
# 25%     280.577500  80.750000    1.087500
# 50%     281.540000  88.000000    1.365000
# 75%     284.330000  92.250000    1.507500
# max     287.340000  96.000000    2.140000

# %% [markdown]
# # <font>6.Visualize the weather data using appropriate plots, such as line charts, bar plots, or scatter plots, to represent temperature changes, precipitation levels, or wind speed variations.</font>

# %%
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(10,5))
sns.scatterplot(x=data_df['Date Time'],
                y=data_df['Temperature'],
                hue=data_df['Weather Description'])

plt.xticks(rotation=90);

# %%
plt.figure(figsize=(10,5))
plt.plot(data_df['Date Time'],data_df['Humidity'])
plt.xticks(rotation=90);

# %% [markdown]
# # <font>7.Apply data aggregation techniques to summarize weather statistics by specific time periods</font>

# %%
data_df.groupby('Date').agg({'Temperature' : 'mean','Wind Speed':'mean'})
# Out:
#             Temperature  Wind Speed
# Date
# 2024-11-04    283.46250     1.25500
# 2024-11-05    281.69375     1.00625
# 2024-11-06    281.20250     1.01125
# 2024-11-07    280.51750     1.13875
# 2024-11-08    280.71625     1.22750
# 2024-11-09    280.84000     1.28250

# %% [markdown]
# # <font>9.Explore and visualize relationships between weather attributes, such as temperature and humidity, using correlation plots or heatmaps.</font>

# %%
sns.heatmap(data_df[['Temperature','Humidity','Wind Speed']].corr(),annot=True,cmap='crest')
# Out:
# <Axes: >
